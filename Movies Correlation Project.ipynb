# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure 

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8)

# read in the data 
df = pd.read_csv(r'C:\Users\tusha\OneDrive\Desktop\movies.csv')

# looking at the data 

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Lets see if there if any missing data 

for col in df.columns:
   pct_missing = np.mean(df[col].isnull())
   print('{} - {}%'. format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# data types for our columns 

df.dtypes
# Out:
# name            str
# rating          str
# genre           str
# year          int64
# released        str
# score       float64
# votes       float64
# director        str
# writer          str
# star            str
# country         str
# budget      float64
# gross       float64
# company         str
# runtime     float64
# dtype: object

# %%
# Fixing missing numbers

numeric_cols = ['budget', 'gross', 'votes', 'runtime', 'score']

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# Checking remaining nulls
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
#Fixing remaining values

df['rating'] = df['rating'].fillna('Unknown')

df['company'] = df['company'].fillna('Unknown')

df['score'] = df['score'].fillna(df['score'].median())

df['votes'] = df['votes'].fillna(df['votes'].median())

df['runtime'] = df['runtime'].fillna(df['runtime'].median())

df['writer'] = df['writer'].fillna('Unknown')
df['country'] = df['country'].fillna('Unknown')

df=df.dropna()

# %%
#Verifying 
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# change Data types of columns 
df['budget'] = df['budget'].fillna(0).astype('int64')

df['gross'] = df['gross'].fillna(0).astype('int64')

# %%
# create correct year column 
df['yearcorrect'] = df['released'].astype(str).str[:4]

# %%
df = df.sort_values(by= ['gross'], inplace=False ,ascending= False)

# %%
pd.set_option('display.max_rows',None)

# %%
df.drop_duplicates(inplace=True)

print(df.shape)
# Out:
# (5436, 16)

# %%
# Budget high correlation
# Company High correlation

# %%
# Scatter Plot with budget vs gross 

plt.scatter(x= df['budget'], y = df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot Budget vs gross seaborn 

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"Blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method= 'spearman',numeric_only=True) #'kendall','pearson','spearman'
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056269  0.426571  0.313199  0.350679  0.094380
# score    0.056269  1.000000  0.495379 -0.010133  0.182857  0.412992
# votes    0.426571  0.495379  1.000000  0.493404  0.745815  0.300944
# budget   0.313199 -0.010133  0.493404  1.000000  0.693670  0.330236
# gross    0.350679  0.182857  0.745815  0.693670  1.000000  0.257112
# runtime  0.094380  0.412992  0.300944  0.330236  0.257112  1.000000

# %%
correlation_matrix = df.corr(method= 'pearson',numeric_only=True)

sns.heatmap(correlation_matrix,annot=True)


plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
#Looks at company
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
df_numerized = df.copy()

for col in df_numerized.columns:
    if not pd.api.types.is_numeric_dtype(df_numerized[col]):
        df_numerized[col] = df_numerized[col].astype('category').cat.codes

df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   387       5      0  2009       528    7.8  1100000.0       787    1265
# 7445   389       5      0  2019       138    8.4   903000.0       106     515
# 3045  4923       5      6  1997       535    7.8  1100000.0       787    1265
# 6663  3656       5      0  2015       530    7.8   876000.0       770    1810
# 7244   390       5      0  2018       146    8.4   897000.0       106     515
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1538       47  237000000  2847246203     1388    162.0            7
# 7445  1474       47  356000000  2797501328      987    181.0            5
# 3045  1076       47  200000000  2201647264     1388    194.0            7
# 6663   357       47  245000000  2069521700      949    138.0            7
# 7244  1474       47  321000000  2048359754      987    149.0            5

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
correlation_matrix = df_numerized.corr(method= 'pearson',numeric_only=True)

sns.heatmap(correlation_matrix,annot=True)


plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029987
#              genre          0.009617
#              year           0.024435
#              released      -0.005896
#              score          0.014955
#              votes          0.012915
#              director       0.013699
#              writer         0.011602
#              star          -0.007109
#              country       -0.025562
#              budget         0.023698
#              gross          0.005966
#              company        0.021347
#              runtime        0.010795
#              yearcorrect   -0.007216
# rating       name          -0.029987
#              rating         1.000000
#              genre          0.152486
#              year           0.016474
#              released       0.017126
#              score          0.068304
#              votes          0.003942
#              director       0.014081
#              writer        -0.000861
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368900
# budget       genre         -0.368900
# gross        genre         -0.244380
# genre        gross         -0.244380
# rating       budget        -0.205920
# budget       rating        -0.205920
# gross        rating        -0.182403
# rating       gross         -0.182403
# genre        votes         -0.136457
# votes        genre         -0.136457
# rating       company       -0.095558
# company      rating        -0.095558
# year         genre         -0.073026
# genre        year          -0.073026
# company      genre         -0.072835
# genre        company       -0.072835
# year         country       -0.065468
# country      year          -0.065468
# runtime      genre         -0.060124
# genre        runtime       -0.060124
# score        country       -0.045209
# country      score         -0.045209
# writer       budget        -0.039420
# budget       writer        -0.039420
# year         director      -0.036936
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross        votes          0.614904
# votes        gross          0.614904
# gross        budget         0.740395
# budget       gross          0.740395
# released     yearcorrect    0.996190
# yearcorrect  released       0.996190
# director     director       1.000000
# votes        votes          1.000000
# released     released       1.000000
# score        score          1.000000
# rating       rating         1.000000
# name         name           1.000000
# genre        genre          1.000000
# year         year           1.000000
# budget       budget         1.000000
# country      country        1.000000
# writer       writer         1.000000
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings

# company has low correlation
